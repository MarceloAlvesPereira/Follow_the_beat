# %% [markdown]
# https://developer.spotify.com/documentation/web-api/
# https://developer.spotify.com/
# https://developer.spotify.com/dashboard/login

# %%
# help(sp)

# %%
# https://spotipy.readthedocs.io/en/latest/#
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
cid = '39ad66a6653b4ab9803d223a0a498045'
secret = '0be2ace130d947fb81c1428eb6d741ca'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,1,1):
#     playlist = sp.search(q='year:2018', type='playlist', limit=50,offset=i)
    track_results = sp.search(q='year:2018', type='track', limit=50,offset=i)
#     album_tracks(self, album_id, limit=50, offset=0, market=None)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])

# %%
import pandas as pd
track_dataframe = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})
print(track_dataframe.shape)
track_dataframe.head()
# Out:
# (50, 4)
#          artist_name                                    track_name  \
# 0         Juice WRLD                        All Girls Are The Same
# 1  Schoolgirl Byebye                                     Year,2015
# 2         Juice WRLD                                  Lucid Dreams
# 3      Fleetwood Mac  Rhiannon (Will You Ever Win) - 2018 Remaster
# 4               Joji                      SLOW DANCING IN THE DARK
#
#                  track_id  popularity
# 0  4VXIryQMWpIdGgYR4TrjT1          82
# 1  0UsmyJDsst2xhX1ZiFF3JW          24
# 2  285pBltuF7vW8TeWk8hdRR          84
# 3  4fbwTO3DJ2qryMddov9RbB          49
# 4  0rKtyWc8bvkriBthvHKY8d          82

# %%
track_results = sp.search(q='year:2019', type='track', limit=1, offset=2)
track_results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=year%3A2019&type=track&offset=2&limit=1',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FugQjLquBF4JzATRN70bR'},
#        'href': 'https://api.spotify.com/v1/artists/6FugQjLquBF4JzATRN70bR',
#        'id': '6FugQjLquBF4JzATRN70bR',
#        'name': 'Yot Club',
#        'type': 'artist',
#        'uri': 'spotify:artist:6FugQjLquBF4JzATRN70bR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
# ...

# %%
album_tracks = sp.album_tracks(album_id='60jUlxAOAcsiQUEW0XLroT', limit=50, offset=0)
# type(album_tracks)
album_tracks
# Out:
# {'href': 'https://api.spotify.com/v1/albums/60jUlxAOAcsiQUEW0XLroT/tracks?offset=0&limit=50',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6FugQjLquBF4JzATRN70bR'},
#      'href': 'https://api.spotify.com/v1/artists/6FugQjLquBF4JzATRN70bR',
#      'id': '6FugQjLquBF4JzATRN70bR',
#      'name': 'Yot Club',
#      'type': 'artist',
#      'uri': 'spotify:artist:6FugQjLquBF4JzATRN70bR'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
# ...

# %%
# album_tracks.get(1)
